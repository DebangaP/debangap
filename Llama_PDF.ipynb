# %% [markdown]
# <a href="https://colab.research.google.com/github/DebangaP/debangap/blob/main/Llama_PDF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q llama-index
# !pip install llama-cpp-python
# !pip install transformers
# !pip install accelerate
# !pip install pinecone-client

# %%
from llama_index import VectorStoreIndex, SimpleDirectoryReader, download_loader
from IPython.display import Markdown, display
from pathlib import Path

PDFReader = download_loader("PDFReader")
loader = PDFReader()
documents = SimpleDirectoryReader("PDFs").load_data

documents = loader.load_data(file=Path('./PDFs/HR_Policy.pdf'))

documents
# Out:
# [Document(id_='52b2c567-b311-4dc4-8206-dca81b128601', embedding=None, metadata={'page_label': '1', 'file_name': 'HR_Policy.pdf'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, hash='a554e98bd43b36a75d033fff434864e52f8e963ed5c341ea01aa2cddc30bc469', text='                                                                                                                                               \n \n \n \n \nEMPLOYEE POLICY HANDBOOK  \nHuman Resource Department  \n \n \n  Version  Date of Adoption  Change Reference  Owner  \n Custodian  Approving \nAuthority  \n1 11-Jun-13 Policy on Human Resource  \nreviewed and approved by the \nBoard  Human Resource  \nTeam  Compliance  Team  Board of Directors  \n1.1 8-May-19 Policy on Human Resource \nreviewed and approved by the \nBoard  Human Resource  \nTeam  Compliance  Team  Board of Directors  \n1.2 24-Jan-20 Policy on Human Resource \nreviewed and approved by the \nBoard  Human Resource  \nTeam  Complia
# ...

# %%
in_memory_vector_index = VectorStoreIndex.from_documents(documents)

in_memory_vector_index.storage_context.persist()

query_engine = in_memory_vector_index.as_query_engine()
response = query_engine.query("What is the objective of the HR Policy? ")

display(Markdown(f"<b>{response}</b>"))
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 47.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 33.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 63.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 59.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 4.6 MB/s eta 0:00:00
# ...
# ******
# Could not load OpenAI model. Using default LlamaCPP=llama2-13b-chat. If you intended to use OpenAI, please check your OPENAI_API_KEY.
# Original error:
# No API key found for OpenAI.
# Please set either the OPENAI_API_KEY environment variable or openai.api_key prior to initialization.
# API keys can be found or created at https://platform.openai.com/account/api-keys
#
# ******
# AVX = 1 | AVX2 = 1 | AVX512 = 0 | AVX512_VBMI = 0 | AVX512_VNNI = 0 | FMA = 1 | NEON = 0 | ARM_FMA = 0 | F16C = 1 | FP16_VA = 0 | WASM_SIMD = 0 | BLAS = 0 | SSE3 = 1 | SSSE3 = 1 | VSX = 0 |
# ...

# %%
# !pip install pinecone-client

# %%
from llama_index import StorageContext, VectorStoreIndex, SimpleDirectoryReader, download_loader
from llama_index import ServiceContext, set_global_service_context
from llama_index.vector_stores import PineconeVectorStore
import pinecone
from IPython.display import Markdown, display
from pathlib import Path

#llm = OpenAI(model="gpt-3.5-turbo", temperature=0, max_tokens=256)

# configure service context
service_context = ServiceContext.from_defaults(chunk_size=800, chunk_overlap=20)

PDFReader = download_loader("PDFReader")
loader = PDFReader()
documents = SimpleDirectoryReader("PDFs").load_data

documents = loader.load_data(file=Path('./PDFs/HR_Policy.pdf'))

# init pinecone
pinecone.init(api_key="6", environment="gcp-starter")
pinecone.create_index("quickstart", dimension=384, metric="euclidean", pod_type="p1")

# construct vector store and customize storage context
storage_context = StorageContext.from_defaults(
    vector_store=PineconeVectorStore(pinecone.Index("quickstart"))
)

pinecone_index = VectorStoreIndex.from_documents(documents, storage_context=storage_context)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-eea25af72800> in <cell line: 1>()
# ----> 1 from llama_index import StorageContext, VectorStoreIndex, SimpleDirectoryReader, download_loader
#       2 from llama_index import ServiceContext, set_global_service_context
#       3 from llama_index.vector_stores import PineconeVectorStore
#       4 import pinecone
#       5 from IPython.display import Markdown, display
#
# /usr/local/lib/python3.10/dist-packages/llama_index/__init__.py in <module>
#      18
#      19 # indices
# ---> 20 from llama_index.indices.keyword_table import (
#      21     KeywordTableIndex,
#      22     RAKEKeywordTableIndex,
#
# /usr/local/lib/python3.10/dist-packages/llama_index/indices/__init__.py in <module>
#       2
#       3 # indices
# ----> 4 from llama_index.indices.keyword_table.base import (
#       5     KeywordTableIndex,
# ...

# %%
pinecone.list_indexes()
query_engine = pinecone_index.as_query_engine()
response = query_engine.query("What is the objective of the HR Policy? ")
